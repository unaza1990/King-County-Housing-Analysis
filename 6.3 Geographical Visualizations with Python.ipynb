# %% [markdown]
# # Importing Data and Libraries

# %%
import pandas as pd
import numpy as np
import folium
import json

# %%
# Create a path
geojson_path = '/Users/muhammaddildar/Downloads/us-states.json'

# %%
with open(geojson_path) as file:
    geojson_data = json.load(file)

# %%
geojson_data['features'][0]
# Out:
# {'type': 'Feature',
#  'id': 'AL',
#  'properties': {'name': 'Alabama'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-87.359296, 35.00118],
#     [-85.606675, 34.984749],
#     [-85.431413, 34.124869],
#     [-85.184951, 32.859696],
#     [-85.069935, 32.580372],
#     [-84.960397, 32.421541],
#     [-85.004212, 32.322956],
#     [-84.889196, 32.262709],
#     [-85.058981, 32.13674],
#     [-85.053504, 32.01077],
#     [-85.141136, 31.840985],
#     [-85.042551, 31.539753],
#     [-85.113751, 31.27686],
#     [-85.004212, 31.003013],
#     [-85.497137, 30.997536],
#     [-87.600282, 30.997536],
#     [-87.633143, 30.86609],
#     [-87.408589, 30.674397],
#     [-87.446927, 30.510088],
#     [-87.37025, 30.427934],
#     [-87.518128, 30.280057],
#     [-87.655051, 30.247195],
#     [-87.90699, 30.411504],
#     [-87.934375, 30.657966],
#     [-88.011052, 30.685351],
#     [-88.10416, 30.499135],
#     [-88.137022, 30.318396],
#     [-88.394438, 30.367688],
#     [-88.471115, 31.895754],
#     [-88.241084, 33.796253],
#     [-88.098683, 34.891641],
#     [-88.202745, 34.995703],
#     [-87.359296, 35.00118]]]}}

# %% [markdown]
# # Data Cleaning

# %%
# Load clean dataset
df = pd.read_csv('/Users/muhammaddildar/Desktop/cleaned_kc_house_data.csv')

# %%
# Load the GeoJSON
geojson_path = '/Users/muhammaddildar/Downloads/us-states.json'
with open(geojson_path) as file:
    geojson_data = json.load(file)

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'was_renovated'],
#       dtype='object')

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1  2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2  2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3  2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4  2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
#    was_renovated
# 0              0
# 1              1
# 2              0
# 3              0
# 4              0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Data Wrangling

# %%
# Mapping the first digits of zipcodes to approximate states
zip_to_state = {
    '99': 'Washington',
    '98': 'Washington',
    '97': 'Oregon',
    '94': 'California',
    '95': 'California',
    '90': 'California',
    '80': 'California',
    '85': 'Arizona',
    '84': 'Utah',
    '83': 'Idaho',
    # Add more if needed based on your dataset — King County = Washington
}

# %%
df['STATE_NAME'] = df['zipcode'].astype(str).str[:2].map(zip_to_state)

# %%
df['STATE_NAME'].value_counts()
# Out:
# STATE_NAME
# Washington    21613
# Name: count, dtype: int64

# %%
state_price = df.groupby('STATE_NAME')['price'].mean().reset_index()
state_price.columns = ['STATE_NAME', 'avg_price']

# %%
state_price.head()
# Out:
#    STATE_NAME      avg_price
# 0  Washington  540088.141767

# %% [markdown]
# # Plotting a Choropleth with Folium

# %%
# Create a base map centered on the US
map = folium.Map(location=[47.5, -120.5], zoom_start=6)

# Add choropleth layer
folium.Choropleth(
    geo_data='/Users/muhammaddildar/Downloads/us-states.json',
    data=state_price,
    columns=['STATE_NAME', 'avg_price'],
    key_on='feature.properties.name',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Average House Price'
).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0091ed7cddc4c40bc26920f0563a2d43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0091ed7cddc4c40bc26920f0563a2d43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0091ed7cddc4c40bc26920f0563a2d43 = L.map(
#                 &quot;map_0091ed7cddc4c40bc26920f0563a2d43&quot;,
#                 {
#                     center: [47.5, -120.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2b46b0999bd3513da960e1c9e45bc10 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2b46b0999bd3513da960e1c9e45bc10.addTo(map_0091ed7cddc4c40bc26920f0563a2d43);
#
#
#             var choropleth_54fd398f2ea6092cf1db6dd4d065ab53 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_e02d0d7602998f7993d1bbe43e171c9a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AZ&quot;: case &quot;AR&quot;: case &quot;CA&quot;: case &quot;CO&quot;: case &quot;CT&quot;: case &quot;DE&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;HI&quot;: case &quot;ID&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;KS&quot;: case &quot;KY&quot;: case &quot;LA&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MA&quot;: case &quot;MI&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NE&quot;: case &quot;NV&quot;: case &quot;NH&quot;: case &quot;NJ&quot;: case &quot;NM&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;ND&quot;: case &quot;OH&quot;: case &quot;OK&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;RI&quot;: case &quot;SC&quot;: case &quot;SD&quot;: case &quot;TN&quot;: case &quot;TX&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;VA&quot;: case &quot;WV&quot;: case &quot;WI&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e02d0d7602998f7993d1bbe43e171c9a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e02d0d7602998f7993d1bbe43e171c9a = L.geoJson(null, {
#                 onEachFeature: geo_json_e02d0d7602998f7993d1bbe43e171c9a_onEachFeature,
#
#                 style: geo_json_e02d0d7602998f7993d1bbe43e171c9a_styler,
#             ...{
# }
#         });
#
#         function geo_json_e02d0d7602998f7993d1bbe43e171c9a_add (data) {
#             geo_json_e02d0d7602998f7993d1bbe43e171c9a
#                 .addData(data);
#         }
#             geo_json_e02d0d7602998f7993d1bbe43e171c9a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-131.602021, 55.117982], [-131.569159, 55.28229], [-131.355558, 55.183705], [-131.38842, 55.01392], [-131.645836, 55.035827], [-131.602021, 55.117982]]], [[[-131.832052, 55.42469], [-131.645836, 55.304197], [-131.749898, 55.128935], [-131.832052, 55.189182], [-131.832052, 55.42469]]], [[[-132.976733, 56.437924], [-132.735747, 56.459832], [-132.631685, 56.421493], [-132.664547, 56.273616], [-132.878148, 56.240754], [-133.069841, 56.333862], [-132.976733, 56.437924]]], [[[-133.595627, 56.350293], [-133.162949, 56.317431], [-133.0

# %% [markdown]
# ## Geospatial Analysis Summary
#
# In this analysis, I created a choropleth map using the `folium` library to visualize the **average house prices by U.S. state**, based on the King County housing dataset.
#
# After importing the necessary libraries and datasets, I performed the following steps:
#
# - Extracted state information from the zip code using a custom mapping.
# - Grouped the data by state and calculated the average house price.
# - Mapped the results onto a GeoJSON file representing U.S. states.
#
# ### Key Insight:
# The only state present in the dataset is **Washington**, as the King County data is limited to that region. The average house price in Washington is approximately **$540,088**.
#
# ### Further Questions:
# - How do house prices vary within different counties of Washington?
# - Could this map be expanded with more state-level housing data for a national comparison?

# %%
map.save('/Users/muhammaddildar/Desktop/choropleth_house_prices.html')
